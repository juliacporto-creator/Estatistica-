# %% [markdown]
# <a href="https://colab.research.google.com/github/juliacporto-creator/Estatistica-/blob/main/tarefa03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Júlia Porto - 17901372
#
# Larissa Mei - 17903839
#
# Marianne Adorno - 17995367

# %% [markdown]
# # Tarefa: Atividade em grupo
#
# ## Estrutura: grupos de 3 alunos (já definidos na primeira aula).
#
# ### Objetivo da atividade:
#
# Cada grupo deve construir tabelas de frequência e pelo 3 tipos de gráficos (barras, histograma, dispersão) usando um pequeno conjunto de dados de alimentos. Ao final, entregar um mini-relatório (ou notebook) com as tabelas, gráficos e uma interpretação simples.
#
# ## Passo a passo da atividade
#
# 1.	Escolha do tema
#
# Cada grupo escolhe um tema simples ligado a alimentos. Se não houver dados reais, o grupo pode simular respostas de 15–20 estudantes, mantendo realismo (ex.: baseados na turma ou em dados aproximados de consumo do IBGE).
#
# 2.	Construção da base de dados
#
# Os alunos digitam os dados diretamente em um DataFrame
#
#
# 3.	Tabelas de frequência
#
# Cada grupo deve:
#
# -	Calcular frequências simples e relativas para duas variáveis (uma nominal e uma discreta ou ordinal).
#
# - Innterpretar os resultados
#
# 4.	Gráficos (15 min)
#
# Cada grupo deve produzir:
# -	1 gráfico de barras.
# -	1 histograma.
# - 1 gráfico de dispersão para relacionar duas variáveis.
#
#
# 5.	Mini-relatório (5 min)
#
# - Pode ser um notebook (.ipynb) + relatório em texto (interpretar resultados).

# %%
import pandas as pd

# Read the Excel file into a pandas DataFrame
df_chocolate = pd.read_excel('/content/dados chocolate ideal(1).xlsx')

# Display the first 5 rows of the DataFrame
display(df_chocolate)
# Out:
#     Pessoa        Região     Gênero Tipo de chocolate  \
# 0        1           sul   feminino          ao leite
# 1        2  Centro-oeste   feminino            branco
# 2        3       sudeste  masculino       meio amargo
# 3        4         norte   feminino            amargo
# 4        5      nordeste  masculino            branco
# 5        6           sul  masculino            branco
# 6        7       sudeste   feminino            amargo
# 7        8  Centro-oeste   feminino          ao leite
# 8        9      nordeste   feminino            branco
# 9       10      nordeste  masculino       meio amargo
# 10      11         norte  masculino          ao leite
# 11      12       sudeste   feminino       meio amargo
# 12      13  Centro-oeste  masculino            amargo
# 13      14       sudeste  masculino            branco
# 14      15         norte   feminino          ao leite
# 15      16           sul   feminino       meio amargo
# ...

# %%
# Calculate the simple frequency for 'Tipo de chocolate'
frequency_table = df_chocolate['Tipo de chocolate'].value_counts()

# Display the frequency table
display(frequency_table)
# Out:
# Tipo de chocolate
# branco         6
# ao leite       5
# meio amargo    5
# amargo         4
# Name: count, dtype: int64

# %%
# Calculate the total number of observations
total_observations = frequency_table.sum()

# Calculate the relative frequency
relative_frequency_table = (frequency_table / total_observations) * 100

# Display the relative frequency table
display(relative_frequency_table)
# Out:
# Tipo de chocolate
# branco         30.0
# ao leite       25.0
# meio amargo    25.0
# amargo         20.0
# Name: count, dtype: float64

# %%
# Calculate the absolute frequency for 'Quantas barras de\nChocolate come por semana'
frequency_barras_semana = df_chocolate['Quantas barras de\nChocolate come por semana'].value_counts()

# Display the frequency table
display(frequency_barras_semana)
# Out:
# Quantas barras de\nChocolate come por semana
# 1    5
# 3    5
# 4    3
# 2    3
# 5    2
# 9    1
# 8    1
# Name: count, dtype: int64

# %%
total_observacoes_barras = frequency_barras_semana.sum()
relative_frequency_barras = (frequency_barras_semana / total_observacoes_barras) * 100

display(relative_frequency_barras)
# Out:
# Quantas barras de\nChocolate come por semana
# 1    25.0
# 3    25.0
# 4    15.0
# 2    15.0
# 5    10.0
# 9     5.0
# 8     5.0
# Name: count, dtype: float64

# %% [markdown]
# #Tipo de chocolate
# - Chocolate branco é o mais consumido, sendo o preferido por 6 pessoas
# - Em seguida, o chocolate ao leite e o meio amargo são preferidos por 5 pessoas
# -Por último, o chocolate amargo é o menos querido, sendo que, apenas 4 pessoas o preferem.
# #Frequência de consumo semanal
#
# - 25% dos participantes consomem 1 barra por semana
# - Também 25% consomem 3 barras
# - 15% consomem 4 barras
# - Igualomente, 15% consomem 2 barras
# -10% consome 5 barras
# - 8 e 9 barras representam 5% do consumo.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Create a bar chart for 'Tipo de chocolate'
plt.figure(figsize=(10, 6))
sns.barplot(x=frequency_table.index, y=frequency_table.values, palette='viridis')
plt.title('Preferência de Tipos de Chocolate')
plt.xlabel('Tipo de Chocolate')
plt.ylabel('Número de Pessoas')
plt.xticks(rotation=45, ha='right') # Rotate labels for better readability
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_2057/3759470685.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=frequency_table.index, y=frequency_table.values, palette='viridis')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12, 7))
sns.histplot(data=df_chocolate, x='Quantidade em gramas de chocolate', hue='Tipo de chocolate', bins=10, kde=True, palette='viridis')
plt.title('Distribuição da Quantidade em Gramas de Chocolate por Barra e Tipo')
plt.xlabel('Quantidade em Gramas de Chocolate')
plt.ylabel('Frequência')
plt.legend(title='Tipo de Chocolate')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_2057/3471650145.py:9: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(title='Tipo de Chocolate')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.swarmplot(x='Região', y='Quantas barras de\nChocolate come por semana', data=df_chocolate, hue='Região', palette='viridis')
plt.title('Consumo de Barras de Chocolate por Semana por Região')
plt.xlabel('Região')
plt.ylabel('Barras de Chocolate Consumidas por Semana')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Mini relatório dos gráficos
#
#
# ## 1. Preferência de Tipos de Chocolate - gráfico de barras
#
# *   Chocolate Branco é o tipo mais popular, sendo preferido por 6 pessoas.
# *   Chocolate ao Leite e Chocolate Meio Amargo ficam com a segunda posição em preferência, ambos com 5 pessoas cada.
# *   Chocolate Amargo é o menos preferido, com apenas 4 pessoas escolhendo como seu tipo favorito.
#
#
# ## 2. Barras de Chocolate Consumidas por Semana - Gráfico de Barras
#
# *   As quantidades de 1 barra e 3 barras por semana são as mais comuns, com 5 pessoas cada relatando esse consumo.
# *   4 barras e 2 barras por semana são consumidas por 3 pessoas cada.
# *   5 barras por semana são consumidas por 2 pessoas.
# *   As quantidades de 8 barras e 9 barras por semana são as menos frequentes, com apenas 1 pessoa para cada uma dessas categorias.
#
#
# ## 3. Consumo de Barras de Chocolate por Semana por Região
#
# *   Região Sul: Apresenta um consumo concentrado em 1 e 3 barras, com uma exceção de 9 barras, indicando um consumidor atípico.
# *   Região Centro-Oeste: O consumo está distribuído entre 1, 3 e 4 barras.
# *   Região Sudeste: maior variedade de consumo, com pontos em 1, 2, 4, 5 e 8 barras, com concentração em 2, 4 e 5 barras.
# *   Região Norte: Exibe um consumo mais baixo, com a maioria dos pontos em 1, 2 e 3 barras.
# *   Região Nordeste: Nordeste mostra consumo entre 1, 3 e 4 barras

# %%
print(df_chocolate.columns)
# Out:
# Index(['Pessoa', 'Região', 'Gênero', 'Tipo de chocolate',
#        'Quantas barras de\nChocolate come por semana',
#        'Quantidade em gramas de chocolate'],
#       dtype='object')
